# %%
from pyspark.sql import SparkSession
import requests

# Inicialize o SparkSession
spark = SparkSession.builder \
    .appName("Consulta API em Spark") \
    .getOrCreate()

# URL da API
url = "https://dadosabertos.compras.gov.br/modulo-material/1_consultarGrupoMaterial"

# Fazendo a solicitação HTTP
response = requests.get(url)

# Verifica se a solicitação foi bem sucedida
if response.status_code == 200:
    # Convertendo a resposta para JSON
    data = response.json()
    
    # Acessando a chave 'resultado' para obter os dados
    data_resultado = data['resultado']
    
    # Criando DataFrame Spark a partir dos dados
    GrupoMaterial = spark.createDataFrame(data_resultado)
    
    # Exibindo o DataFrame
    GrupoMaterial.show()
else:
    print("Falha ao obter os dados da API:", response.status_code)
# Out:
# +-----------+--------------------+--------------------+-----------+
# |codigoGrupo| dataHoraAtualizacao|           nomeGrupo|statusGrupo|
# +-----------+--------------------+--------------------+-----------+
# |         11|2021-10-16T09:16:...|MATERIAIS BÉLICOS...|       true|
# |         54|2021-10-16T09:16:...|ESTRUTURAS E ANDA...|       true|
# |         22|2021-10-16T09:16:...|EQUIPAMENTOS FERR...|       true|
# |         35|2021-10-16T09:16:...|EQUIPAMENTOS COME...|       true|
# |         96|2021-10-16T09:16:...|MINÉRIOS, MINERAI...|       true|
# |         13|2021-10-16T09:16:...|MUNIÇÕES E EXPLOS...|       true|
# |         36|2021-10-16T09:16:...|MÁQUINAS PARA IND...|       true|
# |         34|2021-10-16T09:16:...|MAQUINAS PARA TRA...|       true|
# |         78|2021-10-16T09:16:...|EQUIPAMENTOS PARA...|       true|
# |         41|2021-10-16T09:16:...|EQUIPAMENTOS PARA...|       true|
# |         73|2021-10-16T09:16:...|EQUIPAMENTOS PARA...|       true|
# ...

# %%
from pyspark.sql import SparkSession
import requests

# Inicialize o SparkSession
spark = SparkSession.builder \
    .appName("Consulta API em Spark") \
    .getOrCreate()

# URL da API
url = "https://dadosabertos.compras.gov.br/modulo-material/2_consultarClasseMaterial"

# Fazendo a solicitação HTTP
response = requests.get(url)

# Verifica se a solicitação foi bem sucedida
if response.status_code == 200:
    # Convertendo a resposta para JSON
    data = response.json()
    
    # Acessando a chave 'resultado' para obter os dados
    data_resultado = data.get('resultado')
    
    # Verifica se 'resultado' não é None
    if data_resultado:
        # Filtrando valores None
        data_resultado_filtered = [record for record in data_resultado if record is not None]
        
        # Criando DataFrame Spark a partir dos dados
        ClasseMaterial = spark.createDataFrame(data_resultado_filtered)
        
        # Exibindo o DataFrame
        ClasseMaterial.show()
    else:
        print("Nenhum dado encontrado.")
else:
    print("Falha ao obter os dados da API:", response.status_code)
# Out:
# +------------+-----------+--------------------+--------------------+--------------------+------------+
# |codigoClasse|codigoGrupo| dataHoraAtualizacao|          nomeClasse|           nomeGrupo|statusClasse|
# +------------+-----------+--------------------+--------------------+--------------------+------------+
# |        1005|         10|2021-10-16T09:17:...|ARMAS DE FOGO DE ...|           ARMAMENTO|        true|
# |        1010|         10|2021-10-16T09:17:...|ARMAS DE FOGO DE ...|           ARMAMENTO|        true|
# |        1015|         10|2021-10-16T09:17:...|ARMAS DE FOGO DE ...|           ARMAMENTO|        true|
# |        1020|         10|2021-10-16T09:17:...|ARMAS DE FOGO DE ...|           ARMAMENTO|        true|
# |        1025|         10|2021-10-16T09:17:...|ARMAS DE FOGO DE ...|           ARMAMENTO|        true|
# |        1030|         10|2021-10-16T09:17:...|ARMAS DE FOGO DE ...|           ARMAMENTO|        true|
# ...

# %%
from pyspark.sql import SparkSession
import requests

# Inicialize o SparkSession
spark = SparkSession.builder \
    .appName("Consulta API em Spark") \
    .getOrCreate()

# URL da API
url = "https://dadosabertos.compras.gov.br/modulo-material/3_consultarPdmMaterial"

# Fazendo a solicitação HTTP
response = requests.get(url)

# Verifica se a solicitação foi bem sucedida
if response.status_code == 200:
    # Convertendo a resposta para JSON
    data = response.json()
    
    # Acessando a chave 'resultado' para obter os dados
    data_resultado = data.get('resultado')
    
    # Verifica se 'resultado' não é None
    if data_resultado:
        # Filtrando valores None
        data_resultado_filtered = [record for record in data_resultado if record is not None]
        
        # Criando DataFrame Spark a partir dos dados
        PdmMaterial = spark.createDataFrame(data_resultado_filtered)
        
        # Exibindo o DataFrame
        PdmMaterial.show()
    else:
        print("Nenhum dado encontrado.")
else:
    print("Falha ao obter os dados da API:", response.status_code)
# Out:
# +------------+-----------+---------+--------------------+--------------------+--------------------+--------------------+---------+
# |codigoClasse|codigoGrupo|codigoPdm| dataHoraAtualizacao|          nomeClasse|           nomeGrupo|             nomePdm|statusPdm|
# +------------+-----------+---------+--------------------+--------------------+--------------------+--------------------+---------+
# |        7520|         75|      281|2021-10-16T09:21:...|ACESSÓRIOS E DISP...|UTENSÍLIOS DE ESC...|CARTUCHO CANETA T...|     true|
# |        7510|         75|      282|2021-10-16T09:21:...|ARTIGOS PARA ESCR...|UTENSÍLIOS DE ESC...|      PINCEL DESENHO|     true|
# |        7010|         70|      239|2021-10-16T09:21:...|        COMPUTADORES|INFORMÁTICA - EQU...|"SERVIDOR IMPRESSÃO"|    false|
# |        7010|         70|      283|2021-10-16T09:21:...|        COMPUTADORES|INFORMÁTICA - EQU...|         CHAVEADORAS|    false|
# ...

# %%
from pyspark.sql import SparkSession
import requests

# Inicialize o SparkSession
spark = SparkSession.builder \
    .appName("Consulta API em Spark") \
    .getOrCreate()

# URL da API
url = "https://dadosabertos.compras.gov.br/modulo-material/4_consultarItemMaterial"

# Fazendo a solicitação HTTP
response = requests.get(url)

# Verifica se a solicitação foi bem sucedida
if response.status_code == 200:
    # Convertendo a resposta para JSON
    data = response.json()
    
    # Acessando a chave 'resultado' para obter os dados
    data_resultado = data.get('resultado')
    
    # Verifica se 'resultado' não é None
    if data_resultado:
        # Filtrando valores None
        data_resultado_filtered = [record for record in data_resultado if record is not None]
        
        # Criando DataFrame Spark a partir dos dados
        ItemMaterial = spark.createDataFrame(data_resultado_filtered)
        
        # Exibindo o DataFrame
        ItemMaterial.show()
    else:
        print("Nenhum dado encontrado.")
else:
    print("Falha ao obter os dados da API:", response.status_code)
# Out:
# +------------+-----------+----------+---------+--------------------+--------------------+---------------+--------------------+--------------------+--------------------+----------+
# |codigoClasse|codigoGrupo|codigoItem|codigoPdm| dataHoraAtualizacao|       descricaoItem|itemSustentavel|          nomeClasse|           nomeGrupo|             nomePdm|statusItem|
# +------------+-----------+----------+---------+--------------------+--------------------+---------------+--------------------+--------------------+--------------------+----------+
# |        7520|         75|     72940|      281|2021-10-16T09:43:...|CARTUCHO CANETA T...|          false|ACESSÓRIOS E DISP...|UTENSÍLIOS DE ESC...|CARTUCHO CANETA T...|     false|
# |        7510|         75|     30872|      282|2022-05-31T10:41:...|PINCEL DESENHO, N...|          false|ARTIGOS PARA ESCR...|UTENSÍLIOS DE ESC...|      PINCEL DESENHO|      true|
# ...

# %%
from pyspark.sql import SparkSession
import requests

# Inicialize o SparkSession
spark = SparkSession.builder \
    .appName("Consulta API em Spark") \
    .getOrCreate()

# URL da API
url = "https://dadosabertos.compras.gov.br/modulo-material/5_consultarMaterialNaturezaDespesa"

# Fazendo a solicitação HTTP
response = requests.get(url)

# Verifica se a solicitação foi bem sucedida
if response.status_code == 200:
    # Convertendo a resposta para JSON
    data = response.json()
    
    # Acessando a chave 'resultado' para obter os dados
    data_resultado = data.get('resultado')
    
    # Verifica se 'resultado' não é None
    if data_resultado:
        # Filtrando valores None
        data_resultado_filtered = [record for record in data_resultado if record is not None]
        
        # Criando DataFrame Spark a partir dos dados
        MaterialNaturezaDespesa = spark.createDataFrame(data_resultado_filtered)
        
        # Exibindo o DataFrame
        MaterialNaturezaDespesa.show()
    else:
        print("Nenhum dado encontrado.")
else:
    print("Falha ao obter os dados da API:", response.status_code)
# Out:
# +---------------------+---------+--------------------+---------------------+
# |codigoNaturezaDespesa|codigoPdm| nomeNaturezaDespesa|statusNaturezaDespesa|
# +---------------------+---------+--------------------+---------------------+
# |             33903016|        6|MATERIAL DE CONSU...|                 true|
# |             33903016|       11|MATERIAL DE CONSU...|                 true|
# |             33909292|       11|DESPESAS DE EXERC...|                 true|
# |             33903016|       12|MATERIAL DE CONSU...|                 true|
# |             33903016|       17|MATERIAL DE CONSU...|                 true|
# |             33903016|       18|MATERIAL DE CONSU...|                 true|
# |             33909292|       18|DESPESAS DE EXERC...|                 true|
# |             33903016|       20|MATERIAL DE CONSU...|                 true|
# |             44903016|       20|MATERIAL DE CONSU...|                 true|
# ...

# %%
from pyspark.sql import SparkSession
import requests

# Inicialize o SparkSession
spark = SparkSession.builder \
    .appName("Consulta API em Spark") \
    .getOrCreate()

# URL da API
url = "https://dadosabertos.compras.gov.br/modulo-material/6_consultarMaterialUnidadeFornecimento"

# Fazendo a solicitação HTTP
response = requests.get(url)

# Verifica se a solicitação foi bem sucedida
if response.status_code == 200:
    # Convertendo a resposta para JSON
    data = response.json()
    
    # Acessando a chave 'resultado' para obter os dados
    data_resultado = data.get('resultado')
    
    # Verifica se 'resultado' não é None
    if data_resultado:
        # Filtrando valores None
        data_resultado_filtered = [record for record in data_resultado if record is not None]
        
        # Criando DataFrame Spark a partir dos dados
        MaterialUnidadeFornecimento = spark.createDataFrame(data_resultado_filtered)
        
        # Exibindo o DataFrame
        MaterialUnidadeFornecimento.show()
    else:
        print("Nenhum dado encontrado.")
else:
    print("Falha ao obter os dados da API:", response.status_code)
# Out:
# +-----------------------------+---------+--------------------+----------------------------+-----------------------+-----------------------------------+------------------------+------------------+----------------------------+
# |capacidadeUnidadeFornecimento|codigoPdm| dataHoraAtualizacao|descricaoUnidadeFornecimento|nomeUnidadeFornecimento|numeroSequencialUnidadeFornecimento|siglaUnidadeFornecimento|siglaUnidadeMedida|statusUnidadeFornecimentoPdm|
# +-----------------------------+---------+--------------------+----------------------------+-----------------------+-----------------------------------+------------------------+------------------+----------------------------+
# |                          0.0|        1|2021-10-16T09:30:...|        UMA QUANTIDADE NO...|                UNIDADE|                                  1|                      UN|              NULL|                        true|
# ...

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType

# Inicialize o SparkSession
spark = SparkSession.builder \
    .appName("Consulta API em Spark") \
    .getOrCreate()

# URL da API
url = "https://dadosabertos.compras.gov.br/modulo-material/7_consultarMaterialCaracteristicas"

# Fazendo a solicitação HTTP
response = requests.get(url)

# Verifica se a solicitação foi bem sucedida
if response.status_code == 200:
    # Convertendo a resposta para JSON
    data = response.json()
    
    # Acessando a chave 'resultado' para obter os dados
    data_resultado = data.get('resultado')
      
    # Criando DataFrame Spark a partir dos dados e do esquema definido
    MaterialCaracteristicas = spark.createDataFrame(data_resultado, schema=schema)
    
    # Exibindo o DataFrame
    MaterialCaracteristicas.show()
else:
    print("Falha ao obter os dados da API:", response.status_code)
# Out:
# +------+---------+--------+--------+
# |codigo|descricao|vigencia|material|
# +------+---------+--------+--------+
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# |  NULL|     NULL|    NULL|    NULL|
# +------+---------+--------+--------+
# only showing top 20 rows
